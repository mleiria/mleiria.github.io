# %%
import pandas as pd
import tensorflow as tf
import datetime
import numpy as np
from matplotlib import pyplot as plt

# Carrega a extensão TensorBoard
# %load_ext tensorboard

print("Tensor Flow Version:", tf.__version__)
print("Keras Version:", tf.keras.__version__)
# Out:
# Tensor Flow Version: 2.0.0
# Keras Version: 2.2.4-tf

# %%
#@title Função para criar o modelo
def build_model(my_learning_rate):
    """
    Cria e compila um modelo de regressão linear.
    
    Arguments:
    my_learning_rate -- a taxa de aprendizagem
    
    Returns:
    model -- o modelo compilado
    """
    # O modelo mais simples de tf.keras é o sequencial
    # O modelo sequencial pode conter uma ou mais camadas
    model = tf.keras.models.Sequential()
    
    # Topografia do modelo
    # Duas camadas escondidas, cada uma com 3 unidades
    # A camada de output só tem uma unidade (visto que só queremos
    # prever um único valor) e não usa nenhuma função de activação
    model.add(tf.keras.layers.Dense(units=3, activation="tanh", input_shape=(1,)))
    model.add(tf.keras.layers.Dense(units=3, activation="tanh"))
    model.add(tf.keras.layers.Dense(1))
    
    
    # Compilar a topografia do modelo
    # Configurar o treino para minimizar o erro quadrático médio
    model.compile(optimizer=tf.keras.optimizers.RMSprop(lr=my_learning_rate),
                  loss="mean_squared_error",
                  metrics=[tf.keras.metrics.RootMeanSquaredError()])
    
    return model           

#@title Função para treinar o modelo
def train_model(model, feature, label, epochs, batch_size):
    """
    Treina o modelo de acordo com os dados de entrada
    
    Arguments:
    model -- o modelo a ser treinado
    feature -- um array de features (os valores x)
    label -- um array de labels (os valores y = f(x))
    epochs -- numero de epocas de treino
    batch_size -- tamanho do batch
    
    Returns:
    epochs -- Lista de épocas
    rmse -- Raíz quadrada do erro quadrático médio
    """
    
    # Preparar uma diretoria de logs para ser usada pelo tensorboard
    log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
    tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

    # Passa os valores das features e os valores das labels
    # para o modelo. O modelo vai treinar durante o número
    # de epochs especificado e gradualmente vai aprendendo
    # como é que os valores das features se relacionam com
    # os valores das labels
    history = model.fit(x=feature,
                        y=label,
                        batch_size=batch_size,
                        epochs=epochs,
                        callbacks=[tensorboard_callback])
    
    # Gather the trained model's weight and bias.
    trained_weight = model.get_weights()
    trained_bias = model.get_weights()
    print("---------")
    print(trained_weight)
    print("---------")
    # A lista das epocas e guardada em separado
    epochs = history.epoch
    
    # Faz um snapshot do historico de cada epoca
    hist = pd.DataFrame(history.history)

    # Recolhe especificamente a raiz quadrada do erro quadrático médio
    # em cada epoca
    rmse = hist["root_mean_squared_error"]

    return epochs, rmse

print("Definidas as funções create_model e train_model")
# Out:
# Definidas as funções create_model e train_model

# %%
#@title Gráfico para mostrar o modelo treinado
def plot_the_model(feature, label, preds):
    """
    Gráfico que mostra o modelo treinado contra as features e labels
    
    Arguments:
    feature -- array de features que passámos à rede para treino
    label -- array de labels correspondentes às features
    preds -- array de valores previstos pelo modelo
    """
    
    # Nomes para os eixos
    plt.xlabel("feature")
    plt.ylabel("label")
    
    # Valores das features vs. valores das labels
    plt.scatter(feature, label)
    
    # Cria uma representação a encarnado do modelo.
    plt.plot(feature, preds, 'r--')
    
    # Faz o render do scatter plot e da linha encarnada
    plt.show()

#@title Gráfico para mostrar o rmse vs. epochs
def plot_the_loss_curve(epochs, rmse):
    """
    Gráfico da curva de perda (loss vs. epoch)
    
    Arguments:
    epochs -- número de épocas
    rms -- erro quadrático médio
    
    """
    
    plt.figure()
    plt.xlabel("Epoch")
    plt.ylabel("Root Mean Squared Error")
    
    plt.plot(epochs, rmse, label="Loss")
    plt.legend()
    plt.ylim([rmse.min()*0.97, rmse.max()])
    plt.show()

print("Definidas as funções plot_the_model e plot_the_loss_curve.")
# Out:
# Definidas as funções plot_the_model e plot_the_loss_curve.

# %%
def draw_points(n, func):
    """
    Constroi conjuntos de dados de acordo com a função escolhida
    
    Arguments:
    n -- Total de pontos
    func -- Tipo de função (Aceita: sin, power_two, abs, heaviside)
    
    Returns:
    feature -- Um array com as features (valores de x)
    label -- Um array com as labels (valores de y = f(x))
    """
    feature = np.sort(np.random.uniform(-1, 1, n))
    if func == 'sin':
        label = np.sin(feature)
    elif func == 'power_two':
        label = np.power(feature, 2)
    elif func == 'abs':
        label = np.abs(feature)
    elif func == 'heaviside':
        label = np.heaviside(feature, 0)
    else:
        print("Erro")
        return 0, 0
        
    return feature, label

# %%
# my_feature, my_label = draw_points(50, func='power_two')
# my_feature, my_label = draw_points(50, func='sin')
# my_feature, my_label = draw_points(50, func='abs')
my_feature, my_label = draw_points(50, func='heaviside')

# %%
# Limpa os logs das iterações anteriores
# !rm -rf ./logs/ 
    
#Hyper parametros
learning_rate=0.01
epochs=200
my_batch_size=20

my_model = build_model(learning_rate)
epochs, rmse = train_model(my_model, my_feature, my_label, epochs, my_batch_size)
# Out:
# Train on 50 samples
# Epoch 1/200
# 50/50 [==============================] - 1s 27ms/sample - loss: 0.6569 - root_mean_squared_error: 0.8105
# Epoch 2/200
# 50/50 [==============================] - 0s 473us/sample - loss: 0.3319 - root_mean_squared_error: 0.5761
# Epoch 3/200
# 50/50 [==============================] - 0s 565us/sample - loss: 0.2237 - root_mean_squared_error: 0.4730
# Epoch 4/200
# 50/50 [==============================] - 0s 511us/sample - loss: 0.1680 - root_mean_squared_error: 0.4099
# Epoch 5/200
# 50/50 [==============================] - 0s 503us/sample - loss: 0.1349 - root_mean_squared_error: 0.3674
# Epoch 6/200
# 50/50 [==============================] - 0s 569us/sample - loss: 0.1092 - root_mean_squared_error: 0.3304
# Epoch 7/200
# 50/50 [==============================] - 0s 522us/sample - loss: 0.0946 - root_mean_squared_error: 0.3075
# Epoch 8/200
# 50/50 [==============================] - 0s 475us/sample - loss: 0.0797 - root_mean_squared_error: 0.2823
# Epoch 9/200
# 50/50 [==============================] - 0s 536us/sample - loss: 0.0715 - root_mean_squared_error: 0.2673
# Epoch 10/200
# 50/50 [==============================] - 0s 471us/sample - loss: 0.0675 - root_mean_squared_error: 0.2599
# Epoch 11/200
# 50/50 [==============================] - 0s 540us/sample - loss: 0.0638 - root_mean_squared_error: 0.2526
# Epoch 12/200
# 50/50 [==============================] - 0s 508us/sample - loss: 0.0636 - root_mean_squared_error: 0.2521
# Epoch 13/200
# 50/50 [==============================] - 0s 510us/sample - loss: 0.0616 - root_mean_squared_error: 0.2482
# Epoch 14/200
# 50/50 [==============================] - 0s 469us/sample - loss: 0.0620 - root_mean_squared_error: 0.2490
# Epoch 15/200
# 50/50 [==============================] - 0s 574us/sample - loss: 0.0649 - root_mean_squared_error: 0.2547
# Epoch 16/200
# 50/50 [==============================] - 0s 504us/sample - loss: 0.0615 - root_mean_squared_error: 0.2480
# Epoch 17/200
# 50/50 [==============================] - 0s 627us/sample - loss: 0.0581 - root_mean_squared_error: 0.2411
# Epoch 18/200
# 50/50 [==============================] - 0s 464us/sample - loss: 0.0593 - root_mean_squared_error: 0.2436
# Epoch 19/200
# 50/50 [==============================] - 0s 547us/sample - loss: 0.0578 - root_mean_squared_error: 0.2404
# Epoch 20/200
# 50/50 [==============================] - 0s 586us/sample - loss: 0.0558 - root_mean_squared_error: 0.2363
# Epoch 21/200
# 50/50 [==============================] - 0s 562us/sample - loss: 0.0578 - root_mean_squared_error: 0.2404
# Epoch 22/200
# 50/50 [==============================] - 0s 456us/sample - loss: 0.0534 - root_mean_squared_error: 0.2311
# Epoch 23/200
# 50/50 [==============================] - 0s 587us/sample - loss: 0.0533 - root_mean_squared_error: 0.2309
# Epoch 24/200
# 50/50 [==============================] - 0s 615us/sample - loss: 0.0517 - root_mean_squared_error: 0.2275
# Epoch 25/200
# 50/50 [==============================] - 0s 488us/sample - loss: 0.0491 - root_mean_squared_error: 0.2215
# Epoch 26/200
# 50/50 [==============================] - 0s 501us/sample - loss: 0.0465 - root_mean_squared_error: 0.2156
# Epoch 27/200
# 50/50 [==============================] - 0s 651us/sample - loss: 0.0444 - root_mean_squared_error: 0.2107
# Epoch 28/200
# 50/50 [==============================] - 0s 473us/sample - loss: 0.0421 - root_mean_squared_error: 0.2052
# Epoch 29/200
# 50/50 [==============================] - 0s 660us/sample - loss: 0.0444 - root_mean_squared_error: 0.2106
# Epoch 30/200
# 50/50 [==============================] - 0s 624us/sample - loss: 0.0395 - root_mean_squared_error: 0.1988
# Epoch 31/200
# 50/50 [==============================] - 0s 545us/sample - loss: 0.0406 - root_mean_squared_error: 0.2016
# Epoch 32/200
# 50/50 [==============================] - 0s 557us/sample - loss: 0.0365 - root_mean_squared_error: 0.1909
# Epoch 33/200
# 50/50 [==============================] - 0s 596us/sample - loss: 0.0359 - root_mean_squared_error: 0.1894
# Epoch 34/200
# 50/50 [==============================] - 0s 605us/sample - loss: 0.0338 - root_mean_squared_error: 0.1838
# Epoch 35/200
# 50/50 [==============================] - 0s 590us/sample - loss: 0.0319 - root_mean_squared_error: 0.1787
# Epoch 36/200
# 50/50 [==============================] - 0s 571us/sample - loss: 0.0309 - root_mean_squared_error: 0.1756
# Epoch 37/200
# 50/50 [==============================] - 0s 562us/sample - loss: 0.0290 - root_mean_squared_error: 0.1703
# Epoch 38/200
# 50/50 [==============================] - 0s 593us/sample - loss: 0.0288 - root_mean_squared_error: 0.1698
# Epoch 39/200
# 50/50 [==============================] - 0s 559us/sample - loss: 0.0279 - root_mean_squared_error: 0.1670
# Epoch 40/200
# 50/50 [==============================] - 0s 536us/sample - loss: 0.0281 - root_mean_squared_error: 0.1675
# Epoch 41/200
# 50/50 [==============================] - 0s 548us/sample - loss: 0.0269 - root_mean_squared_error: 0.1639
# Epoch 42/200
# 50/50 [==============================] - 0s 550us/sample - loss: 0.0280 - root_mean_squared_error: 0.1673
# Epoch 43/200
# 50/50 [==============================] - 0s 577us/sample - loss: 0.0281 - root_mean_squared_error: 0.1675
# Epoch 44/200
# 50/50 [==============================] - 0s 616us/sample - loss: 0.0247 - root_mean_squared_error: 0.1573
# Epoch 45/200
# 50/50 [==============================] - 0s 557us/sample - loss: 0.0290 - root_mean_squared_error: 0.1704
# Epoch 46/200
# 50/50 [==============================] - 0s 484us/sample - loss: 0.0278 - root_mean_squared_error: 0.1667
# Epoch 47/200
# 50/50 [==============================] - 0s 582us/sample - loss: 0.0252 - root_mean_squared_error: 0.1587
# Epoch 48/200
# 50/50 [==============================] - 0s 635us/sample - loss: 0.0236 - root_mean_squared_error: 0.1538
# Epoch 49/200
# 50/50 [==============================] - 0s 626us/sample - loss: 0.0244 - root_mean_squared_error: 0.1562
# Epoch 50/200
# 50/50 [==============================] - 0s 643us/sample - loss: 0.0234 - root_mean_squared_error: 0.1528
# Epoch 51/200
# 50/50 [==============================] - 0s 591us/sample - loss: 0.0239 - root_mean_squared_error: 0.1546
# Epoch 52/200
# 50/50 [==============================] - 0s 547us/sample - loss: 0.0265 - root_mean_squared_error: 0.1629
# Epoch 53/200
# 50/50 [==============================] - 0s 600us/sample - loss: 0.0228 - root_mean_squared_error: 0.1511
# Epoch 54/200
# 50/50 [==============================] - 0s 580us/sample - loss: 0.0218 - root_mean_squared_error: 0.1476
# Epoch 55/200
# 50/50 [==============================] - 0s 536us/sample - loss: 0.0216 - root_mean_squared_error: 0.1469
# Epoch 56/200
# 50/50 [==============================] - 0s 471us/sample - loss: 0.0227 - root_mean_squared_error: 0.1508
# Epoch 57/200
# 50/50 [==============================] - 0s 576us/sample - loss: 0.0216 - root_mean_squared_error: 0.1470
# Epoch 58/200
# 50/50 [==============================] - 0s 522us/sample - loss: 0.0211 - root_mean_squared_error: 0.1453
# Epoch 59/200
# 50/50 [==============================] - 0s 587us/sample - loss: 0.0222 - root_mean_squared_error: 0.1489
# Epoch 60/200
# 50/50 [==============================] - 0s 628us/sample - loss: 0.0204 - root_mean_squared_error: 0.1427
# Epoch 61/200
# 50/50 [==============================] - 0s 599us/sample - loss: 0.0213 - root_mean_squared_error: 0.1459
# Epoch 62/200
# 50/50 [==============================] - 0s 534us/sample - loss: 0.0240 - root_mean_squared_error: 0.1549
# Epoch 63/200
# 50/50 [==============================] - 0s 662us/sample - loss: 0.0208 - root_mean_squared_error: 0.1441
# Epoch 64/200
# 50/50 [==============================] - 0s 518us/sample - loss: 0.0202 - root_mean_squared_error: 0.1422
# Epoch 65/200
# 50/50 [==============================] - 0s 599us/sample - loss: 0.0204 - root_mean_squared_error: 0.1429
# Epoch 66/200
# 50/50 [==============================] - 0s 605us/sample - loss: 0.0210 - root_mean_squared_error: 0.1451
# Epoch 67/200
# 50/50 [==============================] - 0s 573us/sample - loss: 0.0193 - root_mean_squared_error: 0.1388
# Epoch 68/200
# 50/50 [==============================] - 0s 595us/sample - loss: 0.0182 - root_mean_squared_error: 0.1350
# Epoch 69/200
# 50/50 [==============================] - 0s 520us/sample - loss: 0.0186 - root_mean_squared_error: 0.1364
# Epoch 70/200
# 50/50 [==============================] - 0s 540us/sample - loss: 0.0185 - root_mean_squared_error: 0.1358
# Epoch 71/200
# 50/50 [==============================] - 0s 412us/sample - loss: 0.0185 - root_mean_squared_error: 0.1361
# Epoch 72/200
# 50/50 [==============================] - 0s 478us/sample - loss: 0.0166 - root_mean_squared_error: 0.1290
# Epoch 73/200
# 50/50 [==============================] - 0s 495us/sample - loss: 0.0187 - root_mean_squared_error: 0.1368
# Epoch 74/200
# 50/50 [==============================] - 0s 458us/sample - loss: 0.0169 - root_mean_squared_error: 0.1300
# Epoch 75/200
# 50/50 [==============================] - 0s 508us/sample - loss: 0.0175 - root_mean_squared_error: 0.1324
# Epoch 76/200
# 50/50 [==============================] - 0s 467us/sample - loss: 0.0172 - root_mean_squared_error: 0.1310
# Epoch 77/200
# 50/50 [==============================] - 0s 486us/sample - loss: 0.0152 - root_mean_squared_error: 0.1231
# Epoch 78/200
# 50/50 [==============================] - 0s 531us/sample - loss: 0.0187 - root_mean_squared_error: 0.1366
# Epoch 79/200
# 50/50 [==============================] - 0s 613us/sample - loss: 0.0152 - root_mean_squared_error: 0.1233
# Epoch 80/200
# 50/50 [==============================] - 0s 470us/sample - loss: 0.0164 - root_mean_squared_error: 0.1281
# Epoch 81/200
# 50/50 [==============================] - 0s 514us/sample - loss: 0.0158 - root_mean_squared_error: 0.1258
# Epoch 82/200
# 50/50 [==============================] - 0s 466us/sample - loss: 0.0158 - root_mean_squared_error: 0.1255
# Epoch 83/200
# 50/50 [==============================] - 0s 501us/sample - loss: 0.0138 - root_mean_squared_error: 0.1176
# Epoch 84/200
# 50/50 [==============================] - 0s 423us/sample - loss: 0.0132 - root_mean_squared_error: 0.1150
# Epoch 85/200
# 50/50 [==============================] - 0s 421us/sample - loss: 0.0140 - root_mean_squared_error: 0.1184
# Epoch 86/200
# 50/50 [==============================] - 0s 546us/sample - loss: 0.0154 - root_mean_squared_error: 0.1241
# Epoch 87/200
# 50/50 [==============================] - 0s 478us/sample - loss: 0.0125 - root_mean_squared_error: 0.1117
# Epoch 88/200
# 50/50 [==============================] - 0s 529us/sample - loss: 0.0127 - root_mean_squared_error: 0.1128
# Epoch 89/200
# 50/50 [==============================] - 0s 446us/sample - loss: 0.0130 - root_mean_squared_error: 0.1138
# Epoch 90/200
# 50/50 [==============================] - 0s 520us/sample - loss: 0.0117 - root_mean_squared_error: 0.1083
# Epoch 91/200
# 50/50 [==============================] - 0s 391us/sample - loss: 0.0117 - root_mean_squared_error: 0.1084
# Epoch 92/200
# 50/50 [==============================] - 0s 387us/sample - loss: 0.0114 - root_mean_squared_error: 0.1069
# Epoch 93/200
# 50/50 [==============================] - 0s 510us/sample - loss: 0.0109 - root_mean_squared_error: 0.1046
# Epoch 94/200
# 50/50 [==============================] - 0s 495us/sample - loss: 0.0126 - root_mean_squared_error: 0.1124
# Epoch 95/200
# 50/50 [==============================] - 0s 503us/sample - loss: 0.0113 - root_mean_squared_error: 0.1063
# Epoch 96/200
# 50/50 [==============================] - 0s 613us/sample - loss: 0.0103 - root_mean_squared_error: 0.1017
# Epoch 97/200
# 50/50 [==============================] - 0s 468us/sample - loss: 0.0123 - root_mean_squared_error: 0.1109
# Epoch 98/200
# 50/50 [==============================] - 0s 509us/sample - loss: 0.0097 - root_mean_squared_error: 0.0983
# Epoch 99/200
# 50/50 [==============================] - 0s 561us/sample - loss: 0.0106 - root_mean_squared_error: 0.1031
# Epoch 100/200
# 50/50 [==============================] - 0s 516us/sample - loss: 0.0104 - root_mean_squared_error: 0.1017
# Epoch 101/200
# 50/50 [==============================] - 0s 439us/sample - loss: 0.0093 - root_mean_squared_error: 0.0963
# Epoch 102/200
# 50/50 [==============================] - 0s 448us/sample - loss: 0.0087 - root_mean_squared_error: 0.0933
# Epoch 103/200
# 50/50 [==============================] - 0s 442us/sample - loss: 0.0083 - root_mean_squared_error: 0.0913
# Epoch 104/200
# 50/50 [==============================] - 0s 460us/sample - loss: 0.0093 - root_mean_squared_error: 0.0967
# Epoch 105/200
# 50/50 [==============================] - 0s 497us/sample - loss: 0.0103 - root_mean_squared_error: 0.1015
# Epoch 106/200
# 50/50 [==============================] - 0s 482us/sample - loss: 0.0079 - root_mean_squared_error: 0.0887
# Epoch 107/200
# 50/50 [==============================] - 0s 435us/sample - loss: 0.0089 - root_mean_squared_error: 0.0943
# Epoch 108/200
# 50/50 [==============================] - 0s 531us/sample - loss: 0.0085 - root_mean_squared_error: 0.0921
# Epoch 109/200
# 50/50 [==============================] - 0s 557us/sample - loss: 0.0088 - root_mean_squared_error: 0.0938
# Epoch 110/200
# 50/50 [==============================] - 0s 535us/sample - loss: 0.0074 - root_mean_squared_error: 0.0861
# Epoch 111/200
# 50/50 [==============================] - 0s 436us/sample - loss: 0.0072 - root_mean_squared_error: 0.0849
# Epoch 112/200
# 50/50 [==============================] - 0s 512us/sample - loss: 0.0070 - root_mean_squared_error: 0.0837
# Epoch 113/200
# 50/50 [==============================] - 0s 476us/sample - loss: 0.0080 - root_mean_squared_error: 0.0897
# Epoch 114/200
# 50/50 [==============================] - 0s 427us/sample - loss: 0.0065 - root_mean_squared_error: 0.0803
# Epoch 115/200
# 50/50 [==============================] - 0s 506us/sample - loss: 0.0062 - root_mean_squared_error: 0.0787
# Epoch 116/200
# 50/50 [==============================] - 0s 466us/sample - loss: 0.0067 - root_mean_squared_error: 0.0820
# Epoch 117/200
# 50/50 [==============================] - 0s 438us/sample - loss: 0.0062 - root_mean_squared_error: 0.0790
# Epoch 118/200
# 50/50 [==============================] - 0s 417us/sample - loss: 0.0053 - root_mean_squared_error: 0.0728
# Epoch 119/200
# 50/50 [==============================] - 0s 524us/sample - loss: 0.0062 - root_mean_squared_error: 0.0790
# Epoch 120/200
# 50/50 [==============================] - 0s 490us/sample - loss: 0.0065 - root_mean_squared_error: 0.0807
# Epoch 121/200
# 50/50 [==============================] - 0s 466us/sample - loss: 0.0050 - root_mean_squared_error: 0.0709
# Epoch 122/200
# 50/50 [==============================] - 0s 447us/sample - loss: 0.0047 - root_mean_squared_error: 0.0689
# Epoch 123/200
# 50/50 [==============================] - 0s 536us/sample - loss: 0.0048 - root_mean_squared_error: 0.0692
# Epoch 124/200
# 50/50 [==============================] - 0s 396us/sample - loss: 0.0040 - root_mean_squared_error: 0.0631
# Epoch 125/200
# 50/50 [==============================] - 0s 452us/sample - loss: 0.0040 - root_mean_squared_error: 0.0635
# Epoch 126/200
# 50/50 [==============================] - 0s 547us/sample - loss: 0.0041 - root_mean_squared_error: 0.0640
# Epoch 127/200
# 50/50 [==============================] - 0s 562us/sample - loss: 0.0044 - root_mean_squared_error: 0.0666
# Epoch 128/200
# 50/50 [==============================] - 0s 546us/sample - loss: 0.0041 - root_mean_squared_error: 0.0639
# Epoch 129/200
# 50/50 [==============================] - 0s 535us/sample - loss: 0.0040 - root_mean_squared_error: 0.0634
# Epoch 130/200
# 50/50 [==============================] - 0s 482us/sample - loss: 0.0047 - root_mean_squared_error: 0.0686
# Epoch 131/200
# 50/50 [==============================] - 0s 528us/sample - loss: 0.0033 - root_mean_squared_error: 0.0571
# Epoch 132/200
# 50/50 [==============================] - 0s 615us/sample - loss: 0.0037 - root_mean_squared_error: 0.0607
# Epoch 133/200
# 50/50 [==============================] - 0s 545us/sample - loss: 0.0041 - root_mean_squared_error: 0.0643
# Epoch 134/200
# 50/50 [==============================] - 0s 499us/sample - loss: 0.0032 - root_mean_squared_error: 0.0569
# Epoch 135/200
# 50/50 [==============================] - 0s 645us/sample - loss: 0.0034 - root_mean_squared_error: 0.0586
# Epoch 136/200
# 50/50 [==============================] - 0s 628us/sample - loss: 0.0028 - root_mean_squared_error: 0.0527
# Epoch 137/200
# 50/50 [==============================] - 0s 574us/sample - loss: 0.0028 - root_mean_squared_error: 0.0532
# Epoch 138/200
# 50/50 [==============================] - 0s 602us/sample - loss: 0.0034 - root_mean_squared_error: 0.0579
# Epoch 139/200
# 50/50 [==============================] - 0s 584us/sample - loss: 0.0026 - root_mean_squared_error: 0.0509
# Epoch 140/200
# 50/50 [==============================] - 0s 676us/sample - loss: 0.0022 - root_mean_squared_error: 0.0473
# Epoch 141/200
# 50/50 [==============================] - 0s 589us/sample - loss: 0.0029 - root_mean_squared_error: 0.0537
# Epoch 142/200
# 50/50 [==============================] - 0s 520us/sample - loss: 0.0023 - root_mean_squared_error: 0.0478
# Epoch 143/200
# 50/50 [==============================] - 0s 682us/sample - loss: 0.0024 - root_mean_squared_error: 0.0490
# Epoch 144/200
# 50/50 [==============================] - 0s 527us/sample - loss: 0.0024 - root_mean_squared_error: 0.0493
# Epoch 145/200
# 50/50 [==============================] - 0s 444us/sample - loss: 0.0023 - root_mean_squared_error: 0.0476
# Epoch 146/200
# 50/50 [==============================] - 0s 445us/sample - loss: 0.0017 - root_mean_squared_error: 0.0412
# Epoch 147/200
# 50/50 [==============================] - 0s 382us/sample - loss: 0.0021 - root_mean_squared_error: 0.0453
# Epoch 148/200
# 50/50 [==============================] - 0s 505us/sample - loss: 0.0017 - root_mean_squared_error: 0.0409
# Epoch 149/200
# 50/50 [==============================] - 0s 562us/sample - loss: 0.0029 - root_mean_squared_error: 0.0536
# Epoch 150/200
# 50/50 [==============================] - 0s 490us/sample - loss: 0.0028 - root_mean_squared_error: 0.0531
# Epoch 151/200
# 50/50 [==============================] - 0s 631us/sample - loss: 0.0018 - root_mean_squared_error: 0.0426
# Epoch 152/200
# 50/50 [==============================] - 0s 570us/sample - loss: 0.0015 - root_mean_squared_error: 0.0391
# Epoch 153/200
# 50/50 [==============================] - 0s 514us/sample - loss: 0.0024 - root_mean_squared_error: 0.0491
# Epoch 154/200
# 50/50 [==============================] - 0s 572us/sample - loss: 0.0016 - root_mean_squared_error: 0.0394
# Epoch 155/200
# 50/50 [==============================] - 0s 627us/sample - loss: 0.0012 - root_mean_squared_error: 0.0349
# Epoch 156/200
# 50/50 [==============================] - 0s 617us/sample - loss: 0.0016 - root_mean_squared_error: 0.0403
# Epoch 157/200
# 50/50 [==============================] - 0s 632us/sample - loss: 0.0011 - root_mean_squared_error: 0.0336
# Epoch 158/200
# 50/50 [==============================] - 0s 523us/sample - loss: 0.0018 - root_mean_squared_error: 0.0427
# Epoch 159/200
# 50/50 [==============================] - 0s 423us/sample - loss: 0.0016 - root_mean_squared_error: 0.0406
# Epoch 160/200
# 50/50 [==============================] - 0s 391us/sample - loss: 0.0012 - root_mean_squared_error: 0.0348
# Epoch 161/200
# 50/50 [==============================] - 0s 344us/sample - loss: 8.6733e-04 - root_mean_squared_error: 0.0295
# Epoch 162/200
# 50/50 [==============================] - 0s 469us/sample - loss: 0.0013 - root_mean_squared_error: 0.0363
# Epoch 163/200
# 50/50 [==============================] - 0s 364us/sample - loss: 0.0012 - root_mean_squared_error: 0.0352
# Epoch 164/200
# 50/50 [==============================] - 0s 462us/sample - loss: 0.0011 - root_mean_squared_error: 0.0338
# Epoch 165/200
# 50/50 [==============================] - 0s 420us/sample - loss: 0.0014 - root_mean_squared_error: 0.0374
# Epoch 166/200
# 50/50 [==============================] - 0s 513us/sample - loss: 0.0010 - root_mean_squared_error: 0.0321
# Epoch 167/200
# 50/50 [==============================] - 0s 437us/sample - loss: 0.0012 - root_mean_squared_error: 0.0340
# Epoch 168/200
# 50/50 [==============================] - 0s 464us/sample - loss: 0.0013 - root_mean_squared_error: 0.0360
# Epoch 169/200
# 50/50 [==============================] - 0s 412us/sample - loss: 9.7354e-04 - root_mean_squared_error: 0.0312
# Epoch 170/200
# 50/50 [==============================] - 0s 374us/sample - loss: 0.0012 - root_mean_squared_error: 0.0343
# Epoch 171/200
# 50/50 [==============================] - 0s 421us/sample - loss: 0.0014 - root_mean_squared_error: 0.0378
# Epoch 172/200
# 50/50 [==============================] - 0s 556us/sample - loss: 8.0379e-04 - root_mean_squared_error: 0.0284
# Epoch 173/200
# 50/50 [==============================] - 0s 438us/sample - loss: 8.0037e-04 - root_mean_squared_error: 0.0283
# Epoch 174/200
# 50/50 [==============================] - 0s 490us/sample - loss: 0.0015 - root_mean_squared_error: 0.0387
# Epoch 175/200
# 50/50 [==============================] - 0s 411us/sample - loss: 6.5698e-04 - root_mean_squared_error: 0.0256
# Epoch 176/200
# 50/50 [==============================] - 0s 447us/sample - loss: 5.9716e-04 - root_mean_squared_error: 0.0244
# Epoch 177/200
# 50/50 [==============================] - 0s 380us/sample - loss: 8.2337e-04 - root_mean_squared_error: 0.0287
# Epoch 178/200
# 50/50 [==============================] - 0s 497us/sample - loss: 0.0013 - root_mean_squared_error: 0.0367
# Epoch 179/200
# 50/50 [==============================] - 0s 499us/sample - loss: 7.7204e-04 - root_mean_squared_error: 0.0278
# Epoch 180/200
# 50/50 [==============================] - 0s 385us/sample - loss: 6.9791e-04 - root_mean_squared_error: 0.0264
# Epoch 181/200
# 50/50 [==============================] - 0s 359us/sample - loss: 5.7894e-04 - root_mean_squared_error: 0.0241
# Epoch 182/200
# 50/50 [==============================] - 0s 447us/sample - loss: 0.0010 - root_mean_squared_error: 0.0324
# Epoch 183/200
# 50/50 [==============================] - 0s 463us/sample - loss: 0.0010 - root_mean_squared_error: 0.0321
# Epoch 184/200
# 50/50 [==============================] - 0s 437us/sample - loss: 3.7592e-04 - root_mean_squared_error: 0.0194
# Epoch 185/200
# 50/50 [==============================] - 0s 485us/sample - loss: 4.7939e-04 - root_mean_squared_error: 0.0219
# Epoch 186/200
# 50/50 [==============================] - 0s 463us/sample - loss: 0.0011 - root_mean_squared_error: 0.0325
# Epoch 187/200
# 50/50 [==============================] - 0s 474us/sample - loss: 6.9488e-04 - root_mean_squared_error: 0.0264
# Epoch 188/200
# 50/50 [==============================] - 0s 489us/sample - loss: 4.1836e-04 - root_mean_squared_error: 0.0205
# Epoch 189/200
# 50/50 [==============================] - 0s 467us/sample - loss: 5.3026e-04 - root_mean_squared_error: 0.0230
# Epoch 190/200
# 50/50 [==============================] - 0s 491us/sample - loss: 8.7389e-04 - root_mean_squared_error: 0.0296
# Epoch 191/200
# 50/50 [==============================] - 0s 386us/sample - loss: 4.0785e-04 - root_mean_squared_error: 0.0202
# Epoch 192/200
# 50/50 [==============================] - 0s 511us/sample - loss: 5.4817e-04 - root_mean_squared_error: 0.0234
# Epoch 193/200
# 50/50 [==============================] - 0s 467us/sample - loss: 3.2882e-04 - root_mean_squared_error: 0.0181
# Epoch 194/200
# 50/50 [==============================] - 0s 468us/sample - loss: 5.9247e-04 - root_mean_squared_error: 0.0243
# Epoch 195/200
# 50/50 [==============================] - 0s 416us/sample - loss: 0.0015 - root_mean_squared_error: 0.0383
# Epoch 196/200
# 50/50 [==============================] - 0s 446us/sample - loss: 4.1770e-04 - root_mean_squared_error: 0.0204
# Epoch 197/200
# 50/50 [==============================] - 0s 515us/sample - loss: 3.0507e-04 - root_mean_squared_error: 0.0175
# Epoch 198/200
# 50/50 [==============================] - 0s 378us/sample - loss: 2.7102e-04 - root_mean_squared_error: 0.0165
# Epoch 199/200
# 50/50 [==============================] - 0s 526us/sample - loss: 4.1314e-04 - root_mean_squared_error: 0.0203
# Epoch 200/200
# 50/50 [==============================] - 0s 466us/sample - loss: 2.4819e-04 - root_mean_squared_error: 0.0158
# ---------
# [array([[-1.2678506, -4.273191 ,  4.4591436]], dtype=float32), array([ 0.03040079, -0.02459778, -0.01954067], dtype=float32), array([[-1.3079963 , -0.11783119,  1.2761189 ],
#        [-1.2911807 ,  0.05093416,  3.4019678 ],
#        [ 1.4867269 ,  0.0603979 , -2.5251703 ]], dtype=float32), array([-0.03589198,  0.2719231 , -0.03555851], dtype=float32), array([[-0.5028842],
#        [ 0.5369645],
#        [-0.9899514]], dtype=float32), array([0.36019617], dtype=float32)]
# ---------

# %%
# Fazer previsões
preds = my_model.predict(my_feature)
preds = np.squeeze(preds)

# Ver os resultados
plot_the_model(my_feature, my_label, preds)
plot_the_loss_curve(epochs, rmse)

# %%
# %tensorboard --logdir logs/fit
# Out:
# Reusing TensorBoard on port 6006 (pid 3215), started 3:03:58 ago. (Use '!kill 3215' to kill it.)
#       <iframe id="tensorboard-frame-951d7a46bd279a52" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-951d7a46bd279a52");
#           const url = new URL("/", window.location);
#           url.port = 6006;
#           frame.src = url;
#         })();
#       </script>
